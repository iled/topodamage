# %%
import pandas as pd

# %%
age_fn = '~/Downloads/assessments.csv'
damage_fn = '/Users/mac1/git/GEOL2469/resources/TopoDataAnalysis_all.csv'

# %%
damage = pd.read_csv(damage_fn)
damage.columns
# Out:
# Index([u'Site ID', u'Site Type', u'Picture IDs', u'Lat', u'Long', u'street',
#        u'house number', u'Date/Time Collected', u'Person(s) collecting',
#        u'Regional slope direction [Az]',
#        u'Regional slope magnitude [degrees from horizontal]',
#        u'Lithology (if exposed)',
#        u'Damaged Structure [1=sidewalk, 2=road, 3=fence, 4=house-wall, 5=other, 6=Pole,7=Stair]',
#        u'Damage Metrics Length [m]', u'Damage Metrics Area [m^2]',
#        u'Damage Metrics Width [m]', u'Damage Metrics Displacement [m]',
#        u'Damage Metrics Orientation [Az]',
#        u'Damage Metrics Tilt [degree from vertical]',
#        u'Damage Metrics Humockiness (Orientation [Az])',
#        u'Damage Metrics Humockiness (wavelength [m])',
#        u'Damage Metrics Humockiness (Amplitude [m])', u'Damage Metrics Misc',
#        u'magnitude of damage – categorical [1-low, 5 hig]',
#        u'evidence of repair [1-yes, 2-no]',
# ...

# %%
age = pd.read_csv(age_fn)
# Out:
# /Users/mac1/Library/Python/2.7/lib/python/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19,20,29,30,31,38,46,57,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
age.columns
# Out:
# Index([u'PARID', u'PROPERTYHOUSENUM', u'PROPERTYFRACTION', u'PROPERTYADDRESS',
#        u'PROPERTYCITY', u'PROPERTYSTATE', u'PROPERTYUNIT', u'PROPERTYZIP',
#        u'MUNICODE', u'MUNIDESC', u'SCHOOLCODE', u'SCHOOLDESC', u'LEGAL1',
#        u'LEGAL2', u'LEGAL3', u'NEIGHCODE', u'NEIGHDESC', u'TAXCODE',
#        u'TAXDESC', u'TAXSUBCODE', u'TAXSUBCODE_DESC', u'OWNERCODE',
#        u'OWNERDESC', u'CLASS', u'CLASSDESC', u'USECODE', u'USEDESC',
#        u'LOTAREA', u'HOMESTEADFLAG', u'FARMSTEADFLAG', u'CLEANGREEN',
#        u'ABATEMENTFLAG', u'RECORDDATE', u'SALEDATE', u'SALEPRICE', u'SALECODE',
#        u'SALEDESC', u'DEEDBOOK', u'DEEDPAGE', u'PREVSALEDATE',
#        u'PREVSALEPRICE', u'PREVSALEDATE2', u'PREVSALEPRICE2',
#        u'CHANGENOTICEADDRESS1', u'CHANGENOTICEADDRESS2',
#        u'CHANGENOTICEADDRESS3', u'CHANGENOTICEADDRESS4', u'COUNTYBUILDING',
#        u'COUNTYLAND', u'COUNTYTOTAL', u'COUNTYEXEMPTBLDG', u'LOCALBUILDING',
# ...

# %%
cols = ['PROPERTYADDRESS', 'PROPERTYHOUSENUM', 'YEARBLT', 'CONDITION', 'CDU']

# %%
age.loc[age.PROPERTYADDRESS == 'SHELTON AVE', cols].sort_values(by='PROPERTYHOUSENUM').iloc[1:300]
# Out:
#        PROPERTYADDRESS  PROPERTYHOUSENUM  YEARBLT  CONDITION  CDU
# 95632      SHELTON AVE               0.0      NaN        NaN  NaN
# 95631      SHELTON AVE               0.0      NaN        NaN  NaN
# 95618      SHELTON AVE               0.0      NaN        NaN  NaN
# 93391      SHELTON AVE               0.0      NaN        NaN  NaN
# 93390      SHELTON AVE               0.0      NaN        NaN  NaN
# 93389      SHELTON AVE               0.0      NaN        NaN  NaN
# 93320      SHELTON AVE            2630.0   1910.0        4.0   FR
# 93344      SHELTON AVE            2632.0   1910.0        4.0   FR
# 93388      SHELTON AVE            2635.0   1900.0        4.0   FR
# 492949     SHELTON AVE            2637.0   1900.0        4.0   FR
# 93387      SHELTON AVE            2639.0   1900.0        5.0   PR
# 496666     SHELTON AVE            2641.0   1900.0        8.0   VP
# 93375      SHELTON AVE            2643.0      NaN        NaN  NaN
# ...
